# %% [markdown]
# # The Multivariate Repeated Measures ANOVA
# ... The blocks are therefore an *implicit* element of how the model is structured, rather than included *explicitly* as we saw previously.
